# %% [markdown]
# In this notebook we use the `./final/dataset.npz` dataset to train multiple ML models to create a surrogate models. The comparison between models will be presented in the next notebook.
#
# During training process dataset is split into train, test and validate sets of sizes `700000`, `150000` and `150000`.
#
# List of tested methods (with links to used implementations):
# 1. [Neural Networks](https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html)
# 2. Linear regression models:
#     1. [Linear Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression)
#     2. [Ridge Regression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html#sklearn.linear_model.Ridge)
#     3. [Lasso (LARS)](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LassoLars.html#sklearn.linear_model.LassoLars)
#     4. [Elastic Net](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html#sklearn.linear_model.ElasticNet)
# 3. Decistion Trees models:
#     1. [Boosting](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html)
#     2. [Bagging](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingRegressor.html)
#     3. [Random Forrest](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)
#     4. [Extra Trees](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.ExtraTreesRegressor.html)
# 4. [k-nearest neighbors](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html)
#
# For each ML method we use [Optuna](https://optuna.readthedocs.io) to find best performing set of parameters.

# %%
# Loading dataset
import numpy as np

input_and_output = np.load("../final/dataset.npz")
inputs  = input_and_output["inputs"].astype(np.float64)
outputs = input_and_output["outputs"].astype(np.float64)

print(f"inputs shape: {inputs.shape} dtype: {inputs.dtype}, outputs shape: {outputs.shape}, dtype: {outputs.dtype}")
dataset_size = inputs.shape[0]
# Out:
# inputs shape: (1000000, 11) dtype: float64, outputs shape: (1000000, 200), dtype: float64

# %%
# In this problem we are interrested in order of magnitude rather than absolute value of the tumour size.
# To train the models output is first transformed with log_10. When the tumour size is smaller than 10^-9 L, 
# there is no way to find it, so we can limit the lower bound of tumour size with 10^-9

LOWER_LIMIT = -9

def output_transform(outputs: np.array) -> np.array:
    x = np.copy(outputs)
    zeros_in_output = x <= 0
    x[zeros_in_output] = 1
    y = np.log10(x)
    y[zeros_in_output] = LOWER_LIMIT
    y[y < LOWER_LIMIT] = LOWER_LIMIT
    return y
    
def output_untransform(transformed_outputs: np.array) -> np.array:
    lower_limits = transformed_outputs <= LOWER_LIMIT
    z = 10 ** transformed_outputs
    z[lower_limits] = 0
    return z

test_output = np.array([10**(-8), 10**(-5), 10**(-10), 10**(-9),1,2,10,0.0])

print(f"test output {test_output}")
print(f"transformed output: {output_transform(test_output)}")
print(f"original output is untouched after transform: {test_output}")
print(f"transformed and untransformed output: {output_untransform(output_transform(test_output))}")

outputs_order_of_magnitude = output_transform(outputs)
# Out:
# test output [1.e-08 1.e-05 1.e-10 1.e-09 1.e+00 2.e+00 1.e+01 0.e+00]
# transformed output: [-8.      -5.      -9.      -9.       0.       0.30103  1.      -9.     ]
# original output is untouched after transform: [1.e-08 1.e-05 1.e-10 1.e-09 1.e+00 2.e+00 1.e+01 0.e+00]
# transformed and untransformed output: [1.e-08 1.e-05 0.e+00 0.e+00 1.e+00 2.e+00 1.e+01 0.e+00]

# %%
# Input data has an extra column with all ones - that we get rid of before training the model

def drop_treatment(input_data: np.ndarray) -> np.ndarray:
    """Drops treatment data from the dataset"""
    if input_data.shape[1] == 11:
        return input_data[:, 1:]

    return input_data

input_without_treatment = drop_treatment(inputs)

# %%
# Splitting dataset into train, test, validate subsets
train_size = int(dataset_size * 0.7)
test_size = int(dataset_size * 0.15)

X_train = input_without_treatment[:train_size, :]
Y_train = outputs_order_of_magnitude[:train_size, :]
print(f"train sizes: {X_train.shape}, {Y_train.shape}")
X_test = input_without_treatment[train_size:(train_size + test_size), :]
Y_test = outputs_order_of_magnitude[train_size:(train_size + test_size), :]
print(f"test sizes: {X_test.shape}, {Y_test.shape}")
# Out:
# train sizes: (700000, 10), (700000, 200)
# test sizes: (150000, 10), (150000, 200)

# %%
# scaling inputs
from sklearn.preprocessing import MinMaxScaler
import pickle
from pathlib import Path


LOGNORMAL_PARAMETERS = (1, 2)

class CustomScaler:
    def __init__(self):
        super().__init__()
        self.scaler = MinMaxScaler()
        self.plot_loval = [0.0] * len(LOGNORMAL_PARAMETERS)
        self.plot_hival = [1.0] * len(LOGNORMAL_PARAMETERS)

    def transform(self, x: np.ndarray, copy=None) -> np.ndarray:
        res = self.scaler.transform(x)
        for i, parameter_index in enumerate(LOGNORMAL_PARAMETERS):
            res[:, parameter_index] = (x[:, parameter_index] - self.plot_loval[i]) / (self.plot_hival[i] - self.plot_loval[i])

        return res

    def fit(self, x, copy=None):
        self.scaler.fit(x)
        for i, parameter_index in enumerate(LOGNORMAL_PARAMETERS):
            column_values = x[:, parameter_index]

            quantile_1, quantile_3 = np.quantile(column_values, [0.25, 0.75], axis=0)
            iqr = quantile_3 - quantile_1

            loval = quantile_1 - 1.5 * iqr
            hival = quantile_3 + 1.5 * iqr

            wiskhi = np.compress(column_values <= hival, column_values)
            wisklo = np.compress(column_values >= loval, column_values)
            actual_hival = np.max(wiskhi)
            actual_loval = np.min(wisklo)

            self.plot_loval[i] = actual_loval
            self.plot_hival[i] = actual_hival

        return self

    def inverse_transform(self, x, copy=None):
        res = self.scaler.inverse_transform(x)
        for i, parameter_index in enumerate(LOGNORMAL_PARAMETERS):
            res[:, parameter_index] = x[:, parameter_index] * (self.plot_hival[i] - self.plot_loval[i]) + self.plot_loval[i]
        return res

scaler_path = Path(f"../final/scaler.pickle")
scaler = None
if scaler_path.exists():
    with scaler_path.open("rb") as scaler_file:
        scaler = pickle.load(scaler_file)
else:
    scaler = CustomScaler().fit(X_train)
    with scaler_path.open("wb") as opened_file:
        pickle.dump(scaler, opened_file)

X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# applying pca to outputs
from sklearn.decomposition import PCA


PCA_COMPONENTS=12

pca_path = Path(f"../final/pca{PCA_COMPONENTS}.pickle")

if pca_path.exists():
    with pca_path.open("rb") as opened_file:
        pca = pickle.load(opened_file)
    Y_train_pca = pca.transform(Y_train)
else: 
    pca = PCA(n_components=PCA_COMPONENTS)
    Y_train_pca = pca.fit_transform(Y_train)
    with pca_path.open("wb") as opened_file:
        pickle.dump(pca, opened_file)

print(pca.explained_variance_ratio_)
# Out:
# [9.63422836e-01 3.45880317e-02 1.13584299e-03 7.00114229e-04
#  8.85658857e-05 3.47212159e-05 1.46535285e-05 6.29722232e-06
#  3.64216009e-06 2.04051841e-06 1.09718389e-06 6.53377990e-07]

# %%
# Example of limitting running time of the loop by scheduling an sigalrm and adding a handler for it.

import optuna
import time
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import psutil
import os
import signal

class TimeoutError(Exception):
    pass

def timeout_handler(*args):
    raise TimeoutError(f"timeout {args}")

def keyboard_interrupt_handler(*args):
    os.kill(os.getpid(), signal.SIGINT)
    
signal.signal(signal.SIGALRM, timeout_handler)

try:
    signal.alarm(2)
    time.sleep(1)
    signal.alarm(0)
    print(f"1. no exception")
except TimeoutError as e:
    print(f"1. message: {e}") 
except KeyboardInterrupt as e:
    print(f"1. KEYBOARD: {e}") 

try:
    signal.alarm(2)
    time.sleep(5)
    signal.alarm(0)
    print(f"2. no exception")
except TimeoutError as e:
    print(f"2. message: {e}")
except KeyboardInterrupt as e:
    print(f"2. keyboard: {e}")
# Out:
# 1. no exception
# 2. message: timeout (14, <frame at 0x12ac55f10, file '/var/folders/xz/pys3pfc567s9bszzmlt87ytm0000gn/T/ipykernel_22073/3465348698.py', line 35, code <module>>)

# %%
# Hyperparameter optimization for neural network

from sklearn.neural_network import MLPRegressor

common_params={
    "tol": 1e-5,
    "n_iter_no_change": 5,
    "random_state": 42,
    "warm_start": False
}

def objective(trial):
    global common_params
    
    phase = min((trial.number // 30), 3)
    training_sizes = (0.03, 0.1, 0.3, 1.0)
    training_max_duration_s = (300, 600, 1200, 3600)
    
    max_iter = [1000, 2000, 4000, 8000][phase]
    batch_size = [500, 500, 1000, 2000][phase]
    
    alpha = trial.suggest_float("alpha", 0.001, 1.0, log=True)
    learning_rate = trial.suggest_categorical("learning_rate", ["constant", "invscaling", "adaptive"])
    learning_rate_init = trial.suggest_float("learning_rate_init", 0.0001, 0.05, log=True)
    power_t = trial.suggest_float("power_t", 0.1, 2.0, log=True) if learning_rate == "invscaling" else 0.5
    
    model_params = {
        "max_iter": max_iter,
        "batch_size": batch_size,
        
        "alpha": alpha,
        "learning_rate": learning_rate,
        "learning_rate_init": learning_rate_init,
        "power_t": power_t,
        
        "hidden_layer_sizes": [
            trial.suggest_int(f"layer1/3", 600, 1200, step=200),
            trial.suggest_int(f"layer2/3", 50, 400, step=50),
            *([trial.suggest_int(f"layer3/3", 10, 50, step=10)])
        ],
        **common_params
    }
    
    trial.set_user_attr("model_params", model_params)
    
    model = MLPRegressor(**trial.user_attrs["model_params"])
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    trial.set_user_attr("training_size", training_size)
    max_duration_s = training_max_duration_s[phase]
    trial.set_user_attr("max_duration_s", max_duration_s)
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        signal.alarm(0)
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
    except TimeoutError:
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="MLPRegressor", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    previous_handler = signal.signal(signal.SIGALRM, keyboard_interrupt_handler)
    study.optimize(objective, n_trials=trials_due)
    signal.signal(signal.SIGALRM, previous_handler)
    
print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 13:55:56,629] A new study created in RDB with name: MLPRegressor
# [I 2023-03-01 13:56:24,522] Trial 0 finished with value: 0.0030842948816073206 and parameters: {'alpha': 0.21188838304714536, 'learning_rate': 'constant', 'learning_rate_init': 0.0006235441962792657, 'layer1/3': 800, 'layer2/3': 100, 'layer3/3': 40}. Best is trial 0 with value: 0.0030842948816073206.
# [I 2023-03-01 13:58:03,293] Trial 1 finished with value: 0.0014728136016113513 and parameters: {'alpha': 0.007141506073780994, 'learning_rate': 'adaptive', 'learning_rate_init': 0.000568931303833518, 'layer1/3': 800, 'layer2/3': 400, 'layer3/3': 30}. Best is trial 1 with value: 0.0014728136016113513.
# [I 2023-03-01 13:58:47,599] Trial 2 finished with value: 0.0026766198554106623 and parameters: {'alpha': 0.06127437245280689, 'learning_rate': 'constant', 'learning_rate_init': 0.0008351837928541461, 'layer1/3': 800, 'layer2/3': 400, 'layer3/3': 50}. Best is trial 1 with value: 0.0014728136016113513.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-01 14:03:50,761] Trial 3 finished with value: 0.0011847221295802261 and parameters: {'alpha': 0.6609184662355871, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0003251095076662141, 'layer1/3': 800, 'layer2/3': 50, 'layer3/3': 50}. Best is trial 3 with value: 0.0011847221295802261.
# [I 2023-03-01 14:04:35,144] Trial 4 finished with value: 0.0015665922752487577 and parameters: {'alpha': 0.09018820251828379, 'learning_rate': 'adaptive', 'learning_rate_init': 0.004468832479826438, 'layer1/3': 1000, 'layer2/3': 250, 'layer3/3': 20}. Best is trial 3 with value: 0.0011847221295802261.
# [I 2023-03-01 14:05:21,871] Trial 5 finished with value: 0.0009387949246958149 and parameters: {'alpha': 0.058285906574352266, 'learning_rate': 'constant', 'learning_rate_init': 0.011220981944718274, 'layer1/3': 1200, 'layer2/3': 200, 'layer3/3': 30}. Best is trial 5 with value: 0.0009387949246958149.
# [I 2023-03-01 14:09:04,729] Trial 6 finished with value: 0.001149794628551768 and parameters: {'alpha': 0.1558368476644794, 'learning_rate': 'invscaling', 'learning_rate_init': 0.000608160153237222, 'power_t': 0.3238523835590726, 'layer1/3': 1200, 'layer2/3': 300, 'layer3/3': 50}. Best is trial 5 with value: 0.0009387949246958149.
# [I 2023-03-01 14:09:59,333] Trial 7 finished with value: 0.002823401113241186 and parameters: {'alpha': 0.017480854909636846, 'learning_rate': 'invscaling', 'learning_rate_init': 0.0006197031515780197, 'power_t': 0.42357098557832396, 'layer1/3': 1200, 'layer2/3': 100, 'layer3/3': 10}. Best is trial 5 with value: 0.0009387949246958149.
# [I 2023-03-01 14:10:32,686] Trial 8 finished with value: 0.0016707411694204955 and parameters: {'alpha': 0.0266836185463935, 'learning_rate': 'constant', 'learning_rate_init': 0.0059461284047401695, 'layer1/3': 600, 'layer2/3': 400, 'layer3/3': 30}. Best is trial 5 with value: 0.0009387949246958149.
# [I 2023-03-01 14:10:49,083] Trial 9 finished with value: 0.006067900104034011 and parameters: {'alpha': 0.0109143812230865, 'learning_rate': 'adaptive', 'learning_rate_init': 0.04515864043890865, 'layer1/3': 1000, 'layer2/3': 100, 'layer3/3': 50}. Best is trial 5 with value: 0.0009387949246958149.
# [I 2023-03-01 14:11:07,548] Trial 10 finished with value: 0.005635164146830264 and parameters: {'alpha': 0.0014332383454894288, 'learning_rate': 'constant', 'learning_rate_init': 0.01923602087389267, 'layer1/3': 1200, 'layer2/3': 200, 'layer3/3': 20}. Best is trial 5 with value: 0.0009387949246958149.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-01 14:16:13,579] Trial 11 finished with value: 0.0013359320685155899 and parameters: {'alpha': 0.19117081213051726, 'learning_rate': 'invscaling', 'learning_rate_init': 0.00011739943309473796, 'power_t': 0.1457621512080231, 'layer1/3': 1200, 'layer2/3': 250, 'layer3/3': 40}. Best is trial 5 with value: 0.0009387949246958149.
# [I 2023-03-01 14:17:43,188] Trial 12 finished with value: 0.0028604907647823215 and parameters: {'alpha': 0.843494256653874, 'learning_rate': 'invscaling', 'learning_rate_init': 0.003487258121279115, 'power_t': 1.931961499176405, 'layer1/3': 1200, 'layer2/3': 300, 'layer3/3': 40}. Best is trial 5 with value: 0.0009387949246958149.
# [I 2023-03-01 14:19:39,123] Trial 13 finished with value: 0.0008789369963895043 and parameters: {'alpha': 0.054125922258280515, 'learning_rate': 'invscaling', 'learning_rate_init': 0.0017828377259449543, 'power_t': 0.2474950357744384, 'layer1/3': 1000, 'layer2/3': 300, 'layer3/3': 20}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:20:13,067] Trial 14 finished with value: 0.001953454083472416 and parameters: {'alpha': 0.0611504808166406, 'learning_rate': 'invscaling', 'learning_rate_init': 0.009762375621514599, 'power_t': 0.14822303011220841, 'layer1/3': 1000, 'layer2/3': 200, 'layer3/3': 20}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:22:38,645] Trial 15 finished with value: 0.002021376923800737 and parameters: {'alpha': 0.04013655900034748, 'learning_rate': 'constant', 'learning_rate_init': 0.0021033186440215105, 'layer1/3': 1000, 'layer2/3': 300, 'layer3/3': 10}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:23:21,352] Trial 16 finished with value: 0.0019717685960841673 and parameters: {'alpha': 0.026715589442840002, 'learning_rate': 'constant', 'learning_rate_init': 0.0014601892682034538, 'layer1/3': 1000, 'layer2/3': 150, 'layer3/3': 20}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:23:39,673] Trial 17 finished with value: 0.002161162901117888 and parameters: {'alpha': 0.004878588462219792, 'learning_rate': 'invscaling', 'learning_rate_init': 0.011526928342382893, 'power_t': 0.848850701194075, 'layer1/3': 600, 'layer2/3': 350, 'layer3/3': 30}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:25:44,439] Trial 18 finished with value: 0.0015180126163271332 and parameters: {'alpha': 0.11654493197990701, 'learning_rate': 'invscaling', 'learning_rate_init': 0.0019173383544166093, 'power_t': 0.2610767411939257, 'layer1/3': 1200, 'layer2/3': 200, 'layer3/3': 10}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:26:11,787] Trial 19 finished with value: 0.004354745752982069 and parameters: {'alpha': 0.0491556263869558, 'learning_rate': 'constant', 'learning_rate_init': 0.003550987700856671, 'layer1/3': 1000, 'layer2/3': 350, 'layer3/3': 20}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:26:42,627] Trial 20 finished with value: 0.0053742524784295585 and parameters: {'alpha': 0.4501572043830981, 'learning_rate': 'constant', 'learning_rate_init': 0.025484228567520466, 'layer1/3': 1200, 'layer2/3': 150, 'layer3/3': 30}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:29:01,944] Trial 21 finished with value: 0.0012516323107028687 and parameters: {'alpha': 0.16738045545197833, 'learning_rate': 'invscaling', 'learning_rate_init': 0.0015733180139180143, 'power_t': 0.30401969151259334, 'layer1/3': 1200, 'layer2/3': 300, 'layer3/3': 40}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:29:38,711] Trial 22 finished with value: 0.005170290741723424 and parameters: {'alpha': 0.27799586812045746, 'learning_rate': 'invscaling', 'learning_rate_init': 0.007290812325377321, 'power_t': 0.23715763904709547, 'layer1/3': 1200, 'layer2/3': 250, 'layer3/3': 30}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:31:15,332] Trial 23 finished with value: 0.0013308927449147494 and parameters: {'alpha': 0.08770141564483291, 'learning_rate': 'invscaling', 'learning_rate_init': 0.0035685853170073873, 'power_t': 0.10094699592861277, 'layer1/3': 1000, 'layer2/3': 350, 'layer3/3': 40}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:34:46,533] Trial 24 finished with value: 0.0009788594947372743 and parameters: {'alpha': 0.11645783266679893, 'learning_rate': 'invscaling', 'learning_rate_init': 0.001120586770214973, 'power_t': 0.5316821914063279, 'layer1/3': 1200, 'layer2/3': 300, 'layer3/3': 20}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:38:01,406] Trial 25 finished with value: 0.0008823974150908036 and parameters: {'alpha': 0.08575701070549284, 'learning_rate': 'invscaling', 'learning_rate_init': 0.0011823010071701223, 'power_t': 0.530992215853774, 'layer1/3': 1000, 'layer2/3': 250, 'layer3/3': 20}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:38:26,507] Trial 26 finished with value: 0.002556487002145088 and parameters: {'alpha': 0.0367067393705702, 'learning_rate': 'invscaling', 'learning_rate_init': 0.0029115239021935053, 'power_t': 0.6618351670274185, 'layer1/3': 1000, 'layer2/3': 150, 'layer3/3': 10}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:39:46,132] Trial 27 finished with value: 0.001224303197236906 and parameters: {'alpha': 0.3522105988608132, 'learning_rate': 'constant', 'learning_rate_init': 0.0023327036518007837, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3': 30}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:40:17,425] Trial 28 finished with value: 0.0018059866054859406 and parameters: {'alpha': 0.0717926764617269, 'learning_rate': 'invscaling', 'learning_rate_init': 0.00558837576013034, 'power_t': 0.7169117522841908, 'layer1/3': 1000, 'layer2/3': 200, 'layer3/3': 20}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:41:54,528] Trial 29 finished with value: 0.0021517629973695517 and parameters: {'alpha': 0.18992152359248182, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0010988868317484228, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3': 30}. Best is trial 13 with value: 0.0008789369963895043.
# [I 2023-03-01 14:44:17,076] Trial 30 finished with value: 0.0006689978343156718 and parameters: {'alpha': 0.020398128461460996, 'learning_rate': 'constant', 'learning_rate_init': 0.002531841550076135, 'layer1/3': 1000, 'layer2/3': 150, 'layer3/3': 20}. Best is trial 30 with value: 0.0006689978343156718.
# [I 2023-03-01 14:45:56,109] Trial 31 finished with value: 0.0005889065282642987 and parameters: {'alpha': 0.02288477060730635, 'learning_rate': 'constant', 'learning_rate_init': 0.0024148208619886257, 'layer1/3': 1000, 'layer2/3': 150, 'layer3/3': 20}. Best is trial 31 with value: 0.0005889065282642987.
# [I 2023-03-01 14:48:03,082] Trial 32 finished with value: 0.0007740212286333561 and parameters: {'alpha': 0.01990306671075577, 'learning_rate': 'constant', 'learning_rate_init': 0.0020270947967792738, 'layer1/3': 1000, 'layer2/3': 150, 'layer3/3': 20}. Best is trial 31 with value: 0.0005889065282642987.
# [I 2023-03-01 14:51:08,862] Trial 33 finished with value: 0.0006346713126157674 and parameters: {'alpha': 0.019167027993374698, 'learning_rate': 'constant', 'learning_rate_init': 0.0026832517877239084, 'layer1/3': 1000, 'layer2/3': 50, 'layer3/3': 10}. Best is trial 31 with value: 0.0005889065282642987.
# [I 2023-03-01 14:52:02,187] Trial 34 finished with value: 0.001178384522190522 and parameters: {'alpha': 0.016514488528492906, 'learning_rate': 'constant', 'learning_rate_init': 0.0025895978732205756, 'layer1/3': 800, 'layer2/3': 50, 'layer3/3': 10}. Best is trial 31 with value: 0.0005889065282642987.
# [I 2023-03-01 14:53:53,311] Trial 35 finished with value: 0.0006975386293995592 and parameters: {'alpha': 0.02113852844860842, 'learning_rate': 'constant', 'learning_rate_init': 0.004690097001792311, 'layer1/3': 1000, 'layer2/3': 100, 'layer3/3': 10}. Best is trial 31 with value: 0.0005889065282642987.
# [I 2023-03-01 14:54:30,673] Trial 36 finished with value: 0.0011558712147952557 and parameters: {'alpha': 0.010761899270041935, 'learning_rate': 'constant', 'learning_rate_init': 0.004943091171153174, 'layer1/3': 800, 'layer2/3': 50, 'layer3/3': 10}. Best is trial 31 with value: 0.0005889065282642987.
# [I 2023-03-01 14:58:05,248] Trial 37 finished with value: 0.00047521739393809536 and parameters: {'alpha': 0.031200236709135465, 'learning_rate': 'constant', 'learning_rate_init': 0.0035782009193145664, 'layer1/3': 1000, 'layer2/3': 100, 'layer3/3': 10}. Best is trial 37 with value: 0.00047521739393809536.
# [I 2023-03-01 15:04:56,186] Trial 38 finished with value: 0.000631564797662682 and parameters: {'alpha': 0.035603525993422, 'learning_rate': 'constant', 'learning_rate_init': 0.0008548199539935314, 'layer1/3': 800, 'layer2/3': 50, 'layer3/3': 10}. Best is trial
-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-02 13:35:54,079] Trial 98 finished with value: 0.00010830637974387415 and parameters: {'alpha': 0.003011040610231708, 'learning_rate': 'adaptive', 'learning_rate_init': 0.00034497759774828457, 'layer1/3': 800, 'layer2/3': 350, 'layer3/3': 30}. Best is trial 94 with value: 8.987444574725626e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-02 14:36:08,682] Trial 99 finished with value: 0.00011917124145897382 and parameters: {'alpha': 0.002644315190379784, 'learning_rate': 'adaptive', 'learning_rate_init': 0.00028741386085654234, 'layer1/3': 800, 'layer2/3': 350, 'layer3/3': 30}. Best is trial 94 with value: 8.987444574725626e-05.
# model: MLPRegressor test dataset error: 8.987444574725626e-05 best_params: {'alpha': 0.0029879519050999255, 'layer1/3': 800, 'layer2/3': 350, 'layer3/3': 30, 'learning_rate': 'adaptive', 'learning_rate_init': 0.00035901468189128335}

# %%
# Test how neural network perform with 10 minute training cap on full dataset
from sklearn.neural_network import MLPRegressor

for learning_rate in ["constant", "invscaling", "adaptive"]:
    max_duration_s = 600
    common_params={
        "tol": 5e-6,
        "n_iter_no_change": 10,
        "random_state": 42,
        "warm_start": False,
        "max_iter": 10000,
        "batch_size": 2000,
        "learning_rate": learning_rate
    }

    def objective(trial):
        global common_params
        global max_duration_s

        alpha = trial.suggest_float("alpha", 0.0001, 1.0, log=True)
        learning_rate_init = trial.suggest_float("learning_rate_init", 0.0001, 0.05, log=True)
        power_t = trial.suggest_float("power_t", 0.1, 2.0, log=True) if learning_rate == "invscaling" else 0.5

        model_params = {
            "alpha": alpha,
            "learning_rate_init": learning_rate_init,
            "power_t": power_t,

            "hidden_layer_sizes": [
                trial.suggest_int(f"layer1/3", 600, 1200, step=200),
                trial.suggest_int(f"layer2/3", 50, 400, step=50),
                *([trial.suggest_int(f"layer3/3", 10, 50, step=10)])
            ],
            **common_params
        }

        trial.set_user_attr("model_params", model_params)

        model = MLPRegressor(**trial.user_attrs["model_params"])
        trial.set_user_attr("training_size", 1.0)
        trial.set_user_attr("max_duration_s", max_duration_s)

        try:
            signal.alarm(max_duration_s)
            model.fit(X_train_scaled, Y_train_pca)
            signal.alarm(0)
            Y_predict_pca = model.predict(X_test_scaled)
            Y_predict = pca.inverse_transform(Y_predict_pca)
            error = mean_squared_error(Y_test, Y_predict)
        except TimeoutError:
            raise optuna.exceptions.TrialPruned()
        return error

    study = optuna.create_study(study_name=f"MLPRegressor_{learning_rate}_{max_duration_s}", storage='sqlite:///../final/optuna.db', load_if_exists=True)
    trials_due = 40 - len(study.trials)
    if trials_due > 0:
        previous_handler = signal.signal(signal.SIGALRM, keyboard_interrupt_handler)
        study.optimize(objective, n_trials=trials_due)
        signal.signal(signal.SIGALRM, previous_handler)

    print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-04 23:31:57,171] Using an existing study with name 'MLPRegressor_constant_600' instead of creating a new one.
# [I 2023-03-04 23:39:12,010] Trial 10 finished with value: 0.00044632827811190873 and parameters: {'alpha': 0.00018594913239497346, 'learning_rate_init': 0.015731157771255038, 'layer1/3': 1000, 'layer2/3': 200, 'layer3/3': 50}. Best is trial 6 with value: 0.00021952360825245112.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-04 23:49:14,756] Trial 11 finished with value: 0.0001567602671812914 and parameters: {'alpha': 0.001036308109465393, 'learning_rate_init': 0.007813604456660923, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3': 30}. Best is trial 11 with value: 0.0001567602671812914.
# [I 2023-03-04 23:58:05,286] Trial 12 finished with value: 0.00034525974800220753 and parameters: {'alpha': 0.0008383598570330053, 'learning_rate_init': 0.013234195428356466, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3':

# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 02:24:55,484] Trial 29 finished with value: 0.00012799958528685236 and parameters: {'alpha': 0.0028644315949148394, 'learning_rate_init': 0.0015121924955907877, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3': 20}. Best is trial 29 with value: 0.00012799958528685236.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 02:34:58,615] Trial 30 finished with value: 0.00018408387222956825 and parameters: {'alpha': 0.006596417743398532, 'learning_rate_init': 0.001087462870903596, 'layer1/3': 1000, 'layer2/3': 250, 'layer3/3': 20}. Best is trial 29 with value: 0.00012799958528685236.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 02:45:01,474] Trial 31 finished with value: 0.00016201880164658241 and parameters: {'alpha': 0.0027474844058487137, 'learning_rate_init': 0.0018020096335111153, 'layer1/3': 800, 'layer2/3': 300, 'layer3/3': 30}. Best is trial 29 with value: 0.00012799958528685236.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 02:55:04,167] Trial 32 finished with value: 7.95338600625236e-05 and parameters: {'alpha': 0.0021976121677802214, 'learning_rate_init': 0.0025086281095413575, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3': 20}. Best is trial 32 with value: 7.95338600625236e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 03:05:11,374] Trial 33 finished with value: 0.0001764783380738596 and parameters: {'alpha': 0.0028240647787825825, 'learning_rate_init': 0.0007753342470145739, 'layer1/3': 600, 'layer2/3': 200, 'layer3/3': 20}. Best is trial 32 with value: 7.95338600625236e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 03:15:14,039] Trial 34 finished with value: 0.0003809054057985747 and parameters: {'alpha': 0.0033563325051067868, 'learning_rate_init': 0.0021769990722103187, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3': 10}. Best is trial 32 with value: 7.95338600625236e-05.
# [I 2023-03-05 03:23:00,780] Trial 35 finished with value: 0.00016720303943005725 and parameters: {'alpha': 0.0017378110491927429, 'learning_rate_init': 0.0030627350081458356, 'layer1/3': 600, 'layer2/3': 350, 'layer3/3': 20}. Best is trial 32 with value: 7.95338600625236e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 03:33:04,810] Trial 36 finished with value: 0.0002507817222330715 and parameters: {'alpha': 0.0089572892562252, 'learning_rate_init': 0.0005176848489593406, 'layer1/3': 800, 'layer2/3': 50, 'layer3/3': 20}. Best is trial 32 with value: 7.95338600625236e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 03:43:10,275] Trial 37 finished with value: 0.0004030541420177215 and parameters: {'alpha': 0.001776605439910731, 'learning_rate_init': 0.00171606603104513, 'layer1/3': 600, 'layer2/3': 300, 'layer3/3': 10}. Best is trial 32 with value: 7.95338600625236e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 03:53:18,722] Trial 38 finished with value: 0.0003387499527225452 and parameters: {'alpha': 0.03256305405022602, 'learning_rate_init': 0.0021429304117056365, 'layer1/3': 800, 'layer2/3': 200, 'layer3/3': 40}. Best is trial 32 with value: 7.95338600625236e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 04:03:22,184] Trial 39 finished with value: 0.8250089828365131 and parameters: {'alpha': 0.003948968845106337, 'learning_rate_init': 0.0031152987798640707, 'layer1/3': 1000, 'layer2/3': 400, 'layer3/3': 10}. Best is trial 32 with value: 7.95338600625236e-05.
# [I 2023-03-05 04:03:22,235] Using an existing study with name 'MLPRegressor_invscaling_600' instead of creating a new one.
# model: MLPRegressor_constant_600 test dataset error: 7.95338600625236e-05 best_params: {'alpha': 0.0021976121677802214, 'layer1/3': 800, 'layer2/3': 250, 'layer3/3': 20, 'learning_rate_init': 0.0025086281095413575}
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 04:13:25,027] Trial 10 finished with value: 0.00014905156362845143 and parameters: {'alpha': 0.07851010613756759, 'learning_rate_init': 0.0024679885446470483, 'power_t': 0.7877040159572618, 'layer1/3': 1000, 'layer2/3': 200, 'layer3/3': 40}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 04:23:27,866] Trial 11 finished with value: 0.0008908958363721395 and parameters: {'alpha': 0.1082909475874544, 'learning_rate_init': 0.002094614855950445, 'power_t': 1.910431309953861, 'layer1/3': 1000, 'layer2/3': 200, 'layer3/3': 40}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 04:33:30,717] Trial 12 finished with value: 0.00037356818866161217 and parameters: {'alpha': 0.05451295305940302, 'learning_rate_init': 0.0020084252542920044, 'power_t': 0.7937969995781353, 'layer1/3': 800, 'layer2/3': 200, 'layer3/3': 40}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 04:43:33,800] Trial 13 finished with value: 0.00043305347310292774 and parameters: {'alpha': 0.8692383122480604, 'learning_rate_init': 0.004729831365966791, 'power_t': 0.6897063919161452, 'layer1/3': 1000, 'layer2/3': 250, 'layer3/3': 50}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 04:53:41,236] Trial 14 finished with value: 0.0002748519905809446 and parameters: {'alpha': 0.11854664323219678, 'learning_rate_init': 0.0010909018476617668, 'power_t': 1.2583062000397143, 'layer1/3': 800, 'layer2/3': 150, 'layer3/3': 40}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 05:03:44,445] Trial 15 finished with value: 0.0007857355120335566 and parameters: {'alpha': 0.016669712021354834, 'learning_rate_init': 0.0042271558116366926, 'power_t': 0.5394916723683627, 'layer1/3': 1000, 'layer2/3': 300, 'layer3/3': 50}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 05:13:52,126] Trial 16 finished with value: 0.00024324365772656134 and parameters: {'alpha': 0.22628950798215103, 'learning_rate_init': 0.0009914384676224747, 'power_t': 1.1882870443738704, 'layer1/3': 800, 'layer2/3': 150, 'layer3/3': 40}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 05:23:55,341] Trial 17 finished with value: 0.0007509155656226704 and parameters: {'alpha': 0.05584629796313507, 'learning_rate_init': 0.0444825106740827, 'power_t': 1.0252422723936572, 'layer1/3': 1200, 'layer2/3': 150, 'layer3/3': 40}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 05:33:57,904] Trial 18 finished with value: 0.0011825350427625053 and parameters: {'alpha': 0.976050069975344, 'learning_rate_init': 0.00442804210564968, 'power_t': 0.6318419361727458, 'layer1/3': 1000, 'layer2/3': 150, 'layer3/3': 20}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 05:44:04,733] Trial 19 finished with value: 0.0002234578363257785 and parameters: {'alpha': 0.04035286730941748, 'learning_rate_init': 0.0007472514500801193, 'power_t': 0.8675580907462368, 'layer1/3': 800, 'layer2/3': 100, 'layer3/3': 30}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 05:54:07,535] Trial 20 finished with value: 0.0003242681832082929 and parameters: {'alpha': 0.009473786739866643, 'learning_rate_init': 0.0004336813898707932, 'power_t': 0.44038153835188154, 'layer1/3': 1000, 'layer2/3': 200, 'layer3/3': 30}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 06:04:16,145] Trial 21 finished with value: 0.0001941396967723223 and parameters: {'alpha': 0.040959629453190614, 'learning_rate_init': 0.00099224814660029, 'power_t': 0.8847144825117699, 'layer1/3': 800, 'layer2/3': 100, 'layer3/3': 30}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 06:14:23,610] Trial 22 finished with value: 0.0002726528334073647 and parameters: {'alpha': 0.03730591277131182, 'learning_rate_init': 0.0006335613418966608, 'power_t': 0.8634173562975228, 'layer1/3': 800, 'layer2/3': 100, 'layer3/3': 30}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 06:24:33,301] Trial 23 finished with value: 0.000354309264961159 and parameters: {'alpha': 0.09686069845744727, 'learning_rate_init': 0.0014753204316093665, 'power_t': 0.6873277474806039, 'layer1/3': 800, 'layer2/3': 100, 'layer3/3': 20}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 06:34:41,275] Trial 24 finished with value: 0.0005327236287405296 and parameters: {'alpha': 0.03481678743678902, 'learning_rate_init': 0.0027138571838660063, 'power_t': 0.9888191797941903, 'layer1/3': 800, 'layer2/3': 100, 'layer3/3': 10}. Best is trial 10 with value: 0.00014905156362845143.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 06:44:48,094] Trial 25 finished with value: 0.0001458599680097689 and parameters: {'alpha': 0.007000746945950041, 'learning_rate_init': 0.0007533688951957081, 'power_t': 1.4233644838634325, 'layer1/3': 1000, 'layer2/3': 100, 'layer3/3': 30}. Best is trial 25 with value: 0.0001458599680097689.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 06:54:51,122] Trial 26 finished with value: 0.00041699118839577074 and parameters: {'alpha': 0.00912338966502857, 'learning_rate_init': 0.0002567127936763489, 'power_t': 1.396735609933043, 'layer1/3': 1000, 'layer2/3': 150, 'layer3/3': 20}. Best is trial 25 with value: 0.0001458599680097689.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 07:04:55,753] Trial 27 finished with value: 9.539619281485134e-05 and parameters: {'alpha': 0.005389035139995959, 'learning_rate_init': 0.001587182673560063, 'power_t': 1.533157961904625, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40}. Best is trial 27 with value: 9.539619281485134e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 07:14:59,383] Trial 28 finished with value: 0.00014628856903563245 and parameters: {'alpha': 0.005302072327997018, 'learning_rate_init': 0.002880442693673407, 'power_t': 1.9371077578224951, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40}. Best is trial 27 with value: 9.539619281485134e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 07:25:03,925] Trial 29 finished with value: 9.807122947767859e-05 and parameters: {'alpha': 0.0054488972115042545, 'learning_rate_init': 0.00153032898933898, 'power_t': 1.5808674511139968, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40}. Best is trial 27 with value: 9.539619281485134e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 07:35:08,524] Trial 30 finished with value: 8.527386328374639e-05 and parameters: {'alpha': 0.0037839705738818854, 'learning_rate_init': 0.001572221328811536, 'power_t': 1.529276287774073, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 07:45:13,912] Trial 31 finished with value: 0.00010996826121096143 and parameters: {'alpha': 0.005150551155650201, 'learning_rate_init': 0.0008000000209297288, 'power_t': 1.5208387916595234, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 07:55:18,214] Trial 32 finished with value: 0.0001263261825244548 and parameters: {'alpha': 0.0032967175000612847, 'learning_rate_init': 0.0016083926570657355, 'power_t': 1.5679912972187355, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 50}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 08:05:22,681] Trial 33 finished with value: 0.00025773900389341916 and parameters: {'alpha': 0.0015731963315593512, 'learning_rate_init': 0.0012008617204984006, 'power_t': 1.6342085596910532, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 08:15:27,391] Trial 34 finished with value: 0.0001649565461893313 and parameters: {'alpha': 0.014291901816546663, 'learning_rate_init': 0.0013868779658712832, 'power_t': 1.8685819868515168, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 50}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 08:25:32,586] Trial 35 finished with value: 0.00020189130661833366 and parameters: {'alpha': 0.003963480519076547, 'learning_rate_init': 0.0008813880157719183, 'power_t': 1.3675070006622876, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 08:35:37,387] Trial 36 finished with value: 0.00013151058480101772 and parameters: {'alpha': 0.00174468524322471, 'learning_rate_init': 0.0017362977864829436, 'power_t': 1.5642712480177066, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 50}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 08:45:42,008] Trial 37 finished with value: 0.0012825647692236235 and parameters: {'alpha': 0.004880503071775516, 'learning_rate_init': 0.000552825140036615, 'power_t': 1.188279109906374, 'layer1/3': 1200, 'layer2/3': 400, 'layer3/3': 40}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 08:55:45,145] Trial 38 finished with value: 0.00015355048720665693 and parameters: {'alpha': 0.0010046822122835716, 'learning_rate_init': 0.0003903870140826904, 'power_t': 1.07091320451381, 'layer1/3': 1200, 'layer2/3': 100, 'layer3/3': 40}. Best is trial 30 with value: 8.527386328374639e-05.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 09:05:49,627] Trial 39 finished with value: 0.00014257590380068586 and parameters: {'alpha': 0.002434645155978251, 'learning_rate_init': 0.0013179626044158594, 'power_t': 1.9291045034608665, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 50}. Best is trial 30 with value: 8.527386328374639e-05.
# model: MLPRegressor_invscaling_600 test dataset error: 8.527386328374639e-05 best_params: {'alpha': 0.0037839705738818854, 'layer1/3': 1200, 'layer2/3': 50, 'layer3/3': 40, 'learning_rate_init': 0.001572221328811536, 'power_t': 1.529276287774073}
# [I 2023-03-05 09:05:51,129] Using an existing study with name 'MLPRegressor_adaptive_600' instead of creating a new one.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 09:15:54,132] Trial 10 finished with value: 0.001960311475482657 and parameters: {'alpha': 0.00010373156910349187, 'learning_rate_init': 0.033788340598837056, 'layer1/3': 600, 'layer2/3': 300, 'layer3/3': 40}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 09:25:57,593] Trial 11 finished with value: 0.00023999374595770997 and parameters: {'alpha': 0.02224140543470641, 'learning_rate_init': 0.0005945316844608408, 'layer1/3': 1000, 'layer2/3': 300, 'layer3/3': 50}. Best is trial 4 with value: 0.00013706229839877327.
# [I 2023-03-05 09:33:12,753] Trial 12 finished with value: 0.0001625022125108751 and parameters: {'alpha': 0.002770182539674482, 'learning_rate_init': 0.012072567703886558, 'layer1/3': 600, 'layer2/3': 300, 'layer3/3': 50}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 09:43:15,989] Trial 13 finished with value: 0.0005726209689211147 and parameters: {'alpha': 0.022715055205740135, 'learning_rate_init': 0.0011798269767367565, 'layer1/3': 1000, 'layer2/3': 250, 'layer3/3': 20}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 09:53:18,992] Trial 14 finished with value: 0.0014637688128625354 and parameters: {'alpha': 0.0007363752013988676, 'learning_rate_init': 0.014670184001008467, 'layer1/3': 600, 'layer2/3': 350, 'layer3/3': 40}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 10:03:22,397] Trial 15 finished with value: 0.0001572888382339703 and parameters: {'alpha': 0.007029180842478944, 'learning_rate_init': 0.0029645388787778587, 'layer1/3': 800, 'layer2/3': 400, 'layer3/3': 30}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 10:13:26,524] Trial 16 finished with value: 0.0003239941034633931 and parameters: {'alpha': 0.04823675023183898, 'learning_rate_init': 0.001164766354348017, 'layer1/3': 1200, 'layer2/3': 250, 'layer3/3': 50}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 10:23:29,459] Trial 17 finished with value: 0.0005821876605886131 and parameters: {'alpha': 0.013394625068573269, 'learning_rate_init': 0.005295241385982757, 'layer1/3': 600, 'layer2/3': 350, 'layer3/3': 20}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 10:33:32,847] Trial 18 finished with value: 0.0012665250989261734 and parameters: {'alpha': 0.0030233029423698834, 'learning_rate_init': 0.00010054261406126391, 'layer1/3': 800, 'layer2/3': 350, 'layer3/3': 30}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 10:43:36,150] Trial 19 finished with value: 0.0002950853668473287 and parameters: {'alpha': 0.0800412106489596, 'learning_rate_init': 0.0021917054888789503, 'layer1/3': 1000, 'layer2/3': 250, 'layer3/3': 40}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 10:53:43,899] Trial 20 finished with value: 0.0002233773688876049 and parameters: {'alpha': 0.012191215203178915, 'learning_rate_init': 0.0007348582149600268, 'layer1/3': 600, 'layer2/3': 200, 'layer3/3': 20}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05
. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 13:34:42,627] Trial 36 finished with value: 0.000360441749832674 and parameters: {'alpha': 0.10063629278642172, 'learning_rate_init': 0.004710081602387791, 'layer1/3': 1000, 'layer2/3': 50, 'layer3/3': 10}. Best is trial 4 with value: 0.00013706229839877327.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 13:44:45,596] Trial 37 finished with value: 0.0001240866740246993 and parameters: {'alpha': 0.006777069662715181, 'learning_rate_init': 0.001549679834450489, 'layer1/3': 800, 'layer2/3': 350, 'layer3/3': 20}. Best is trial 37 with value: 0.0001240866740246993.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 13:54:48,494] Trial 38 finished with value: 0.0011695540358443253 and parameters: {'alpha': 0.029817597196672773, 'learning_rate_init': 0.001444550370884262, 'layer1/3': 1000, 'layer2/3': 250, 'layer3/3': 10}. Best is trial 37 with value: 0.0001240866740246993.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2023-03-05 14:04:51,088] Trial 39 finished with value: 0.0016740020906300824 and parameters: {'alpha': 0.6742216880291731, 'learning_rate_init': 0.0009062795157651266, 'layer1/3': 600, 'layer2/3': 350, 'layer3/3': 20}. Best is trial 37 with value: 0.0001240866740246993.
# model: MLPRegressor_adaptive_600 test dataset error: 0.0001240866740246993 best_params: {'alpha': 0.006777069662715181, 'layer1/3': 800, 'layer2/3': 350, 'layer3/3': 20, 'learning_rate_init': 0.001549679834450489}

# %%
# Lasso (Linear with an L1 regularizer) model fit with Least Angle Regression

from sklearn.linear_model import LassoLars

common_params = {
    "random_state": 42
}

def objective(trial):
    global common_params
    phase = min((trial.number // 30), 4)

    training_sizes = (0.03, 0.1, 0.3, 1.0 if psutil.virtual_memory().total > 40 * 10**9 else 0.5)
    training_max_duration_s = (120, 180, 360, 600, 1200)
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    max_iter = [1000, 2000, 4000, 8000][phase]
    
    trial.set_user_attr("training_size", training_size)
    trial.set_user_attr("max_duration_s", max_duration_s)
    trial.set_user_attr("common_params", {
        "mas_iter": max_iter,
        **common_params
    })
    
    alpha = trial.suggest_float("alpha", 0.00001, 0.1, log=True)
    degree = trial.suggest_int("polynomial degree", 1, 5)
    
    model = make_pipeline(
        PolynomialFeatures(degree),
        LassoLars(
            alpha=alpha,
            max_iter=max_iter,
            **common_params
        )
    )
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except TimeoutError:
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="LassoLars", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)
    
print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 11:36:26,138] Using an existing study with name 'LassoLars' instead of creating a new one.
# model: LassoLars test dataset error: 0.024058488345672494 best_params: {'alpha': 0.0002644100143852797, 'polynomial degree': 5}

# %%
# Linear Regression model (least squares)

from sklearn.linear_model import LinearRegression

MAX_POLYNOMIAL_DEGREE = 4


def objective(trial):
    global common_params
    phase = min((trial.number // MAX_POLYNOMIAL_DEGREE), 4)

    training_sizes = (0.03, 0.1, 0.3, 1.0 if psutil.virtual_memory().total > 40 * 10**9 else 0.5)
    training_max_duration_s = (120, 180, 360, 600)
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    
    degree = (trial.number % MAX_POLYNOMIAL_DEGREE) + 1
    trial.set_user_attr("training_size", training_size)
    trial.set_user_attr("max_duration_s", max_duration_s)
    trial.set_user_attr("polynomial degree", degree)
    
    model = make_pipeline(
        PolynomialFeatures(degree),
        LinearRegression()
    )
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except TimeoutError:
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="LinearRegression", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 16 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)

print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 11:36:26,240] Using an existing study with name 'LinearRegression' instead of creating a new one.
# model: LinearRegression test dataset error: 0.02956507698551257 best_params: {}

# %%
# Linear least squares with l2 regularization
from sklearn.linear_model import Ridge

common_params = {
    "random_state": 42,
    "tol": 1e-5
}

MAX_POLYNOMIAL_DEGREE = 3

def objective(trial):
    global common_params
    phase = min((trial.number // 30), 4)

    training_sizes = (0.03, 0.1, 0.3, 1.0 if psutil.virtual_memory().total > 40 * 10**9 else 0.5)
    training_max_duration_s = (240, 360, 600, 1200)
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    max_iter = [1000, 2000, 4000, 8000][phase]
    
    trial.set_user_attr("training_size", training_size)
    trial.set_user_attr("max_duration_s", max_duration_s)
    trial.set_user_attr("common_params", {
        "mas_iter": max_iter,
        **common_params
    })
    
    alpha = trial.suggest_float("alpha", 0.00001, 0.1, log=True)
    solver = trial.suggest_categorical("solver", ["svd", "cholesky", "lsqr", "sparse_cg", "sag", "saga"])
    degree = trial.suggest_int("polynomial degree", 1, MAX_POLYNOMIAL_DEGREE)
    
    model = make_pipeline(
        PolynomialFeatures(degree),
        Ridge(
            alpha=alpha,
            max_iter=max_iter,
            solver=solver,
            **common_params
        )
    )
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except TimeoutError:
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="Ridge", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)
    
print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 11:36:26,319] Using an existing study with name 'Ridge' instead of creating a new one.
# model: Ridge test dataset error: 0.05766259340561942 best_params: {'alpha': 0.099006936464171, 'polynomial degree': 3, 'solver': 'svd'}

# %%
# Linear regression with combined L1 and L2 priors as regularizer
from sklearn.linear_model import ElasticNet

common_params = {
    "random_state": 42,
    "tol": 1e-5
}

MAX_POLYNOMIAL_DEGREE = 3

def objective(trial):
    global common_params
    phase = min((trial.number // 30), 4)

    training_sizes = (0.03, 0.1, 0.3, 1.0)
    training_max_duration_s = (240, 360, 600, 1200)
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    max_iter = [20000, 40000, 80000, 160000][phase]
    
    trial.set_user_attr("training_size", training_size)
    trial.set_user_attr("max_duration_s", max_duration_s)
    trial.set_user_attr("common_params", {
        "max_iter": max_iter,
        **common_params
    })
    
    l1_ratio = trial.suggest_float("l1_ratio", 0.0, 1.0)
    alpha = trial.suggest_float("alpha", 0.00001, 1.0, log=True)
    fit_intercept = trial.suggest_categorical("fit_intercept", [True, False])
    degree = trial.suggest_int("polynomial degree", 1, MAX_POLYNOMIAL_DEGREE)
    
    model = make_pipeline(
        PolynomialFeatures(degree),
        ElasticNet(
            alpha=alpha,
            l1_ratio=l1_ratio,
            fit_intercept=fit_intercept,
            max_iter=max_iter,
            **common_params
        )
    )
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except TimeoutError:
        raise optuna.exceptions.TrialPruned()
    return error

try:
    optuna.delete_study(study_name="ElasticNet", storage='sqlite:///../final/optuna.db')
except:
    pass

study = optuna.create_study(study_name="ElasticNet", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 20 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)
    
print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 11:36:26,486] A new study created in RDB with name: ElasticNet
# [I 2023-03-01 11:36:28,861] Trial 0 finished with value: 0.1415348449670532 and parameters: {'l1_ratio': 0.05778395898737221, 'alpha': 0.00010890908496958414, 'fit_intercept': True, 'polynomial degree': 2}. Best is trial 0 with value: 0.1415348449670532.
# [I 2023-03-01 11:36:30,327] Trial 1 finished with value: 0.6070698262213244 and parameters: {'l1_ratio': 0.9588414663412709, 'alpha': 0.9844233575379248, 'fit_intercept': False, 'polynomial degree': 3}. Best is trial 0 with value: 0.1415348449670532.
# [I 2023-03-01 11:36:42,218] Trial 2 finished with value: 0.14912926052409606 and parameters: {'l1_ratio': 0.47305777105203706, 'alpha': 0.0021004298957074505, 'fit_intercept': False, 'polynomial degree': 2}. Best is trial 0 with value: 0.1415348449670532.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.197e+05, tolerance: 3.478e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.896e+03, tolerance: 1.214e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.330e+02, tolerance: 4.179e-02
#   model = cd_fast.enet_coordinate_descent(
# [I 2023-03-01 11:41:04,010] Trial 3 pruned.
# [I 2023-03-01 11:41:04,788] Trial 4 finished with value: 0.3234962493074397 and parameters: {'l1_ratio': 0.1264100370052864, 'alpha': 0.005719278797544084, 'fit_intercept': False, 'polynomial degree': 1}. Best is trial 0 with value: 0.1415348449670532.
# [I 2023-03-01 11:41:22,570] Trial 5 finished with value: 0.21629287783413814 and parameters: {'l1_ratio': 0.21802792860817066, 'alpha': 0.031241455416971663, 'fit_intercept': False, 'polynomial degree': 3}. Best is trial 0 with value: 0.1415348449670532.
# [I 2023-03-01 11:41:23,394] Trial 6 finished with value: 0.23655719922586096 and parameters: {'l1_ratio': 0.8052017620571531, 'alpha': 0.03995620331856687, 'fit_intercept': True, 'polynomial degree': 2}. Best is trial 0 with value: 0.1415348449670532.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.514e+03, tolerance: 3.477e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.704e+00, tolerance: 1.214e+00
#   model = cd_fast.enet_coordinate_descent(
# [I 2023-03-01 11:45:06,067] Trial 7 finished with value: 0.0688497401893624 and parameters: {'l1_ratio': 0.8232154401659981, 'alpha': 3.6587810657886685e-05, 'fit_intercept': True, 'polynomial degree': 3}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:45:53,750] Trial 8 finished with value: 0.08516649940724173 and parameters: {'l1_ratio': 0.375480935773012, 'alpha': 0.0005551714791328113, 'fit_intercept': True, 'polynomial degree': 3}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:46:05,963] Trial 9 finished with value: 0.14173990578595308 and parameters: {'l1_ratio': 0.8769307952567611, 'alpha': 0.0015005442828882778, 'fit_intercept': False, 'polynomial degree': 2}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:46:06,638] Trial 10 finished with value: 0.32230946409396055 and parameters: {'l1_ratio': 0.6379948907228331, 'alpha': 1.0118348505551793e-05, 'fit_intercept': True, 'polynomial degree': 1}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:48:17,739] Trial 11 finished with value: 0.07170656448390812 and parameters: {'l1_ratio': 0.42657357450800304, 'alpha': 0.00015289213955593656, 'fit_intercept': True, 'polynomial degree': 3}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:50:31,257] Trial 12 finished with value: 0.06929498638790281 and parameters: {'l1_ratio': 0.66208405203457, 'alpha': 0.0001225417648760564, 'fit_intercept': True, 'polynomial degree': 3}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:53:45,918] Trial 13 finished with value: 0.0688617754219499 and parameters: {'l1_ratio': 0.6444741028391193, 'alpha': 6.62641969317693e-05, 'fit_intercept': True, 'polynomial degree': 3}. Best is trial 7 with value: 0.0688497401893624.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.744e+03, tolerance: 3.477e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.659e+02, tolerance: 1.214e+00
#   model = cd_fast.enet_coordinate_descent(
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.950e-02, tolerance: 4.179e-02
#   model = cd_fast.enet_coordinate_descent(
# [I 2023-03-01 11:58:42,440] Trial 14 pruned.
# [I 2023-03-01 11:58:44,358] Trial 15 finished with value: 0.1414892192615545 and parameters: {'l1_ratio': 0.9701550387134932, 'alpha': 6.282102941508346e-05, 'fit_intercept': True, 'polynomial degree': 2}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:59:51,823] Trial 16 finished with value: 0.07492690573234832 and parameters: {'l1_ratio': 0.5667114768360406, 'alpha': 0.00034252533617734366, 'fit_intercept': True, 'polynomial degree': 3}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 11:59:52,470] Trial 17 finished with value: 0.32230879747272057 and parameters: {'l1_ratio': 0.7679198437970848, 'alpha': 2.702385453203663e-05, 'fit_intercept': True, 'polynomial degree': 1}. Best is trial 7 with value: 0.0688497401893624.
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.583e+03, tolerance: 3.477e+01
#   model = cd_fast.enet_coordinate_descent(
# /Users/tpawlowski/workspace/dokstud/lazarou2020/venv/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.572e+00, tolerance: 1.214e+00
#   model = cd_fast.enet_coordinate_descent(
# [I 2023-03-01 12:03:38,873] Trial 18 finished with value: 0.06885557566370162 and parameters: {'l1_ratio': 0.8188677893858365, 'alpha': 3.577885069221632e-05, 'fit_intercept': True, 'polynomial degree': 3}. Best is trial 7 with value: 0.0688497401893624.
# [I 2023-03-01 12:03:41,136] Trial 19 finished with value: 0.14150291163576503 and parameters: {'l1_ratio': 0.847656441311183, 'alpha': 1.4751266894820062e-05, 'fit_intercept': True, 'polynomial degree': 2}. Best is trial 7 with value: 0.0688497401893624.
# model: ElasticNet test dataset error: 0.0688497401893624 best_params: {'alpha': 3.6587810657886685e-05, 'fit_intercept': True, 'l1_ratio': 0.8232154401659981, 'polynomial degree': 3}

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import HistGradientBoostingRegressor

def objective(trial):
    trial_params = {}
    # poisson requires y > 0 which is not true in this case
    trial_params["loss"] = trial.suggest_categorical("loss", ["squared_error", "absolute_error", "quantile"])
    
    if trial_params["loss"] == "quantile":
        trial_params["quantile"] = trial.suggest_float("quantile", 0, 1)
    
    trial_params["learning_rate"] = trial.suggest_float("learning_rate", 0.00001, 0.5, log=True)
    trial_params["max_iter"] = trial.suggest_int("max_iter", 20, 200, step=20)
    if trial.suggest_categorical("regularize", [True, False]):
        trial_params["l2_regularization"] = trial.suggest_float("l2_regularization", 0.00001, 1.0, log=True)
    
    model = MultiOutputRegressor(HistGradientBoostingRegressor(
        random_state=42,
        **trial_params
    ))
    
    phase = min((trial.number // 30), 4)
    
    training_sizes = (0.03, 0.1, 0.3, 1.0)
    training_max_duration_s = (240, 360, 600, 1200)
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except KeyboardInterrupt as e:
        raise e
    except Exception as e:
        print(e)
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="HistGradientBoostingRegressor", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)

print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 12:03:41,793] Using an existing study with name 'HistGradientBoostingRegressor' instead of creating a new one.
# model: HistGradientBoostingRegressor test dataset error: 0.008577411300669628 best_params: {'l2_regularization': 0.001871946506788565, 'learning_rate': 0.1651977983535292, 'loss': 'squared_error', 'max_iter': 160, 'regularize': True}

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import BaggingRegressor

def objective(trial):
    phase = min((trial.number // 30), 4)
    
    training_sizes = (0.1, 0.1, 0.3, 1.0)
    training_max_duration_s = (240, 360, 600, 1200)
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    
    trial_params = {}
    
    trial_params["n_estimators"] = trial.suggest_int("max_iter", 10, 110, step=20)
    trial_params["max_samples"] = trial.suggest_int("max_samples", 10000, (training_size // 10000) * 10000, step=10000)
    trial_params["max_features"] = trial.suggest_int("max_features", 1, X_train_scaled.shape[1])
    trial_params["bootstrap"] = trial.suggest_categorical("bootstrap", [True, False])
    if trial_params["bootstrap"]:
        trial_params["oob_score"] = trial.suggest_categorical("oob_score", [True, False])
    trial_params["bootstrap_features"] = trial.suggest_categorical("bootstrap_features", [True, False])
    
    model = MultiOutputRegressor(BaggingRegressor(
        n_jobs=-1,
        random_state=42,
        **trial_params
    ))
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except KeyboardInterrupt as e:
        raise e
    except Exception as e:
        print(e)
        raise optuna.exceptions.TrialPruned()
    return error

# try:
#     optuna.delete_study(study_name="BaggingRegressor", storage='sqlite:///../final/optuna.db')
# except:
#     pass

study = optuna.create_study(study_name="BaggingRegressor", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)
    
print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 12:03:41,895] Using an existing study with name 'BaggingRegressor' instead of creating a new one.
# model: BaggingRegressor test dataset error: 0.012123721671364409 best_params: {'bootstrap': True, 'bootstrap_features': False, 'max_features': 10, 'max_iter': 50, 'max_samples': 320000, 'oob_score': False}

# %%
from sklearn.ensemble import RandomForestRegressor

def objective(trial):
    phase = min((trial.number // 30), 4)

    training_sizes = (0.01, 0.03, 0.1, 0.3, 1.0)
    training_max_duration_s = (120, 180, 360, 600, 1200)
    
    n_estimators = trial.suggest_int("n_estimators", 10, 200, step=10)
    criterion = trial.suggest_categorical("criterion", ["squared_error", "absolute_error", "friedman_mse"])
    min_samples_split = trial.suggest_int("min_samples_split", 2, 5)
    bootstrap = trial.suggest_categorical("bootstrap", [True])
    max_samples=trial.suggest_float("max_samples", 0.0, 0.2) if bootstrap else None
    max_features=trial.suggest_int("max_features", 1, X_train_scaled.shape[1] // 2)
    
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        criterion=criterion,
        min_samples_split=min_samples_split,
        bootstrap=bootstrap,
        max_samples=max_samples,
        max_features=max_features,
        n_jobs=-1,
        random_state=42
    )
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except KeyboardInterrupt as e:
        raise e
    except:
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="RandomForrest", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)

print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 12:03:42,031] A new study created in RDB with name: RandomForrest
# [I 2023-03-01 12:04:02,168] Trial 0 finished with value: 0.17594851993192578 and parameters: {'n_estimators': 150, 'criterion': 'absolute_error', 'min_samples_split': 4, 'bootstrap': True, 'max_samples': 0.06166565672349294, 'max_features': 3}. Best is trial 0 with value: 0.17594851993192578.
# [I 2023-03-01 12:04:03,733] Trial 1 finished with value: 0.2394594945929994 and parameters: {'n_estimators': 200, 'criterion': 'friedman_mse', 'min_samples_split': 4, 'bootstrap': True, 'max_samples': 0.05148208511841046, 'max_features': 2}. Best is trial 0 with value: 0.17594851993192578.
# [I 2023-03-01 12:04:13,641] Trial 2 finished with value: 0.12898461251525709 and parameters: {'n_estimators': 70, 'criterion': 'absolute_error', 'min_samples_split': 3, 'bootstrap': True, 'max_samples': 0.10475322296497798, 'max_features': 5}. Best is trial 2 with value: 0.12898461251525709.
# [I 2023-03-01 12:04:14,799] Trial 3 finished with value: 0.17245433924739167 and parameters: {'n_estimators': 110, 'criterion': 'squared_error', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.0605642263455741, 'max_features': 3}. Best is trial 2 with value: 0.12898461251525709.
# [I 2023-03-01 12:04:15,478] Trial 4 finished with value: 0.18611684177336563 and parameters: {'n_estimators': 10, 'criterion': 'squared_error', 'min_samples_split': 4, 'bootstrap': True, 'max_samples': 0
and parameters: {'n_estimators': 60, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.1659571853793228, 'max_features': 4}. Best is trial 92 with value: 0.0276166738609489.
# [I 2023-03-01 12:32:30,281] Trial 97 finished with value: 0.028435380661269535 and parameters: {'n_estimators': 60, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.16355033860391427, 'max_features': 4}. Best is trial 92 with value: 0.0276166738609489.
# [I 2023-03-01 12:32:35,644] Trial 98 finished with value: 0.0280496372284091 and parameters: {'n_estimators': 60, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.16324808113304212, 'max_features': 4}. Best is trial 92 with value: 0.0276166738609489.
# [I 2023-03-01 12:32:40,899] Trial 99 finished with value: 0.028094581005230088 and parameters: {'n_estimators': 60, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.1634132936871427, 'max_features': 4}. Best is trial 92 with value: 0.0276166738609489.
# model: RandomForrest test dataset error: 0.0276166738609489 best_params: {'bootstrap': True, 'criterion': 'friedman_mse', 'max_features': 4, 'max_samples': 0.1753336890830068, 'min_samples_split': 2, 'n_estimators': 60}

# %%
from sklearn.ensemble import ExtraTreesRegressor

def objective(trial):
    phase = min((trial.number // 30), 4)

    training_sizes = (0.01, 0.03, 0.1, 0.3, 1.0)
    training_max_duration_s = (120, 180, 360, 600, 1200)
    
    n_estimators = trial.suggest_int("n_estimators", 10, 200)
    criterion = trial.suggest_categorical("criterion", ["squared_error", "absolute_error", "friedman_mse"])
    min_samples_split = trial.suggest_int("min_samples_split", 2, 5)
    bootstrap = trial.suggest_categorical("bootstrap", [True])
    max_samples=trial.suggest_float("max_samples", 0.0, 0.2) if bootstrap else None
    max_features=trial.suggest_int("max_features", 1, X_train_scaled.shape[1] // 2)
    
    model = ExtraTreesRegressor(
        n_estimators=n_estimators,
        criterion=criterion,
        min_samples_split=min_samples_split,
        bootstrap=bootstrap,
        max_samples=max_samples,
        max_features=max_features,
        n_jobs=-1,
        random_state=42
    )
    
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except KeyboardInterrupt as e:
        raise e
    except:
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="ExtraTreesRegressor", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)
    
print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 12:32:41,001] A new study created in RDB with name: ExtraTreesRegressor
# [I 2023-03-01 12:32:46,498] Trial 0 finished with value: 0.322134221928035 and parameters: {'n_estimators': 153, 'criterion': 'absolute_error', 'min_samples_split': 4, 'bootstrap': True, 'max_samples': 0.01255001625674428, 'max_features': 5}. Best is trial 0 with value: 0.322134221928035.
# [I 2023-03-01 12:32:47,571] Trial 1 finished with value: 0.1849629620536771 and parameters: {'n_estimators': 76, 'criterion': 'friedman_mse', 'min_samples_split': 4, 'bootstrap': True, 'max_samples': 0.06194135536751255, 'max_features': 4}. Best is trial 1 with value: 0.1849629620536771.
# [I 2023-03-01 12:33:06,884] Trial 2 finished with value: 0.21881731026489612 and parameters: {'n_estimators': 132, 'criterion': 'absolute_error', 'min_samples_split': 5, 'bootstrap': True, 'max_samples': 0.09732287208421518, 'max_features': 3}. Best is trial 1 with value: 0.1849629620536771.
# [I 2023-03-01 12:33:07,712] Trial 3 finished with value: 0.39815469153689853 and parameters: {'n_estimators': 32, 'criterion': 'squared_error', 'min_samples_split': 4, 'bootstrap': True, 'max_samples': 0.07700986986220291, 'max_features': 1}. Best is trial 1 with value: 0.1849629620536771.
# [I 2023-03-01 12:33:08,651] Trial 4 finished with value: 0.2899027359967534 and parameters: {'n_estimators': 53, 'criterion': 'friedman_mse', 'min_samples_split': 5, 'bootstrap': True, 'max_samples': 0.08152740814905168, 'max_features': 2}. Best is trial 1 with value: 0.1849629620536771.
# [I 2023-03-01 12:33:09,918] Trial 5 finished with value: 0.41397853785042815 and parameters: {'n_estimators': 130, 'criterion': 'friedman_mse', 'min_samples_split': 5, 'bootstrap': True, 'max_samples': 0
 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.16863307801002564, 'max_features': 5}. Best is trial 87 with value: 0.052100753742875566.
# [I 2023-03-01 13:07:55,009] Trial 90 finished with value: 0.03638773556485777 and parameters: {'n_estimators': 191, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.16857020559293848, 'max_features': 5}. Best is trial 90 with value: 0.03638773556485777.
# [I 2023-03-01 13:08:02,240] Trial 91 finished with value: 0.03680891970464449 and parameters: {'n_estimators': 188, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.168425524926101, 'max_features': 5}. Best is trial 90 with value: 0.03638773556485777.
# [I 2023-03-01 13:08:11,252] Trial 92 finished with value: 0.03643529177486731 and parameters: {'n_estimators': 191, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.17785077179318634, 'max_features': 5}. Best is trial 90 with value: 0.03638773556485777.
# [I 2023-03-01 13:08:19,688] Trial 93 finished with value: 0.0358175180075317 and parameters: {'n_estimators': 192, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.17860238105411386, 'max_features': 5}. Best is trial 93 with value: 0.0358175180075317.
# [I 2023-03-01 13:08:27,797] Trial 94 finished with value: 0.0357957769641441 and parameters: {'n_estimators': 191, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.17956913903771338, 'max_features': 5}. Best is trial 94 with value: 0.0357957769641441.
# [I 2023-03-01 13:08:36,673] Trial 95 finished with value: 0.036005642941713906 and parameters: {'n_estimators': 190, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.18315744089397973, 'max_features': 5}. Best is trial 94 with value: 0.0357957769641441.
# [I 2023-03-01 13:08:45,018] Trial 96 finished with value: 0.09952194050363605 and parameters: {'n_estimators': 195, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.178471459616063, 'max_features': 2}. Best is trial 94 with value: 0.0357957769641441.
# [I 2023-03-01 13:08:54,171] Trial 97 finished with value: 0.035638099610715714 and parameters: {'n_estimators': 182, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.18501919599037991, 'max_features': 5}. Best is trial 97 with value: 0.035638099610715714.
# [I 2023-03-01 13:09:03,473] Trial 98 finished with value: 0.035944060946585414 and parameters: {'n_estimators': 183, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.17796655875139478, 'max_features': 5}. Best is trial 97 with value: 0.035638099610715714.
# [I 2023-03-01 13:09:28,625] Trial 99 finished with value: 0.03606047993113789 and parameters: {'n_estimators': 182, 'criterion': 'friedman_mse', 'min_samples_split': 2, 'bootstrap': True, 'max_samples': 0.18324269487734152, 'max_features': 5}. Best is trial 97 with value: 0.035638099610715714.
# model: ExtraTreesRegressor test dataset error: 0.035638099610715714 best_params: {'bootstrap': True, 'criterion': 'friedman_mse', 'max_features': 5, 'max_samples': 0.18501919599037991, 'min_samples_split': 2, 'n_estimators': 182}

# %%
from sklearn.neighbors import KNeighborsRegressor

common_params = {
    "n_jobs": -1
}

def objective(trial):
    phase = min((trial.number // 30), 4)

    training_sizes = (0.01, 0.03, 0.1, 0.3, 1.0)
    training_max_duration_s = (120, 180, 360, 600, 1200)
    training_size = int(training_sizes[phase] * X_train_scaled.shape[0])
    max_duration_s = training_max_duration_s[phase]
    
    trial_params = {}
    trial_params["n_neighbors"] = trial.suggest_int("n_neighbors", 1, 100)
    trial_params["weights"] = trial.suggest_categorical("weights", ["uniform", "distance"])
    trial_params["algorithm"] = trial.suggest_categorical("algorithm", ["ball_tree", "kd_tree", "brute"])
    if trial_params["algorithm"] != "brute":
        trial_params["leaf_size"] = trial.suggest_int("leaf_size", 10, 50)
    trial_params["p"] = trial.suggest_int("p", 1, 5)
    
    model_params = {
        **trial_params,
        **common_params
    }
    trial.set_user_attr("model_params", model_params)
    model = KNeighborsRegressor(**trial.user_attrs["model_params"])
    
    try:
        signal.alarm(max_duration_s)
        model.fit(X_train_scaled[:training_size,:], Y_train_pca[:training_size,:])
        Y_predict_pca = model.predict(X_test_scaled)
        Y_predict = pca.inverse_transform(Y_predict_pca)
        error = mean_squared_error(Y_test, Y_predict)
        signal.alarm(0)
    except KeyboardInterrupt as e:
        raise e
    except Exception as e:
        print(e)
        raise optuna.exceptions.TrialPruned()
    return error

study = optuna.create_study(study_name="KNeighborsRegressor", storage='sqlite:///../final/optuna.db', load_if_exists=True)
trials_due = 100 - len(study.trials)
if trials_due > 0:
    study.optimize(objective, n_trials=trials_due)
    
print(f"model: {study.study_name} test dataset error: {study.best_value} best_params: {study.best_params}")
# Out:
# [I 2023-03-01 13:20:53,485] A new study created in RDB with name: KNeighborsRegressor
# [I 2023-03-01 13:21:55,320] Trial 0 finished with value: 0.2955053826591534 and parameters: {'n_neighbors': 94, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 36, 'p': 3}. Best is trial 0 with value: 0.2955053826591534.
# [I 2023-03-01 13:22:02,371] Trial 1 finished with value: 0.2454018788242259 and parameters: {'n_neighbors': 89, 'weights': 'distance', 'algorithm': 'brute', 'p': 1}. Best is trial 1 with value: 0.2454018788242259.
# [I 2023-03-01 13:22:59,623] Trial 2 finished with value: 0.3138173698459204 and parameters: {'n_neighbors': 89, 'weights': 'uniform', 'algorithm': 'brute', 'p': 5}. Best is trial 1 with value: 0.2454018788242259.
# [I 2023-03-01 13:23:55,900] Trial 3 finished with value: 0.25448517373485685 and parameters: {'n_neighbors': 49, 'weights': 'distance', 'algorithm': 'brute', 'p': 3}. Best is trial 1 with value: 0.2454018788242259.
# [I 2023-03-01 13:24:37,724] Trial 4 finished with value: 0.2948750929844013 and parameters: {'n_neighbors': 86, 'weights': 'distance', 'algorithm': 'kd_tree', 'leaf_size': 30, 'p': 4}. Best is trial 1 with value: 0.2454018788242259.
# [I 2023-03-01 13:25:38,660] Trial 5 finished with value: 0.28805352037836907 and parameters: {'n_neighbors': 76, 'weights': 'distance', 'algorithm': 'ball_tree', 'leaf_size': 45, 'p': 4}. Best is trial 1 with value: 0.2454018788242259.
# [I 2023-03-01 13:25:44,603] Trial 6 finished with value: 0.23508798548905888 and parameters: {'n_neighbors': 62, 'weights': 'uniform', 'algorithm': 'brute', 'p': 1}. Best is trial 6 with value: 0.23508798548905888.
# [I 2023-03-01 13:26:40,170] Trial 7 finished with value: 0.23439938357723292 and parameters: {'n_neighbors': 30, 'weights': 'distance', 'algorithm': 'brute', 'p': 3}. Best is trial 7 with value: 0.23439938357723292.
# [I 2023-03-01 13:27:38,059] Trial 8 finished with value: 0.2295648580770032 and parameters: {'n_neighbors': 10, 'weights': 'uniform', 'algorithm': 'ball_tree', 'leaf_size': 33, 'p': 5}. Best is trial 8 with value: 0.2295648580770032.
# [I 2023-03-01 13:27:54,480] Trial 9 finished with value: 0.21196498486521023 and parameters: {'n_neighbors': 9, 'weights': 'uniform', 'algorithm': 'kd_tree', 'leaf_size': 13, 'p': 3}. Best is trial 9 with value: 0.21196498486521023.
# model: KNeighborsRegressor test dataset error: 0.21196498486521023 best_params: {'algorithm': 'kd_tree', 'leaf_size': 13, 'n_neighbors': 9, 'p': 3, 'weights': 'uniform'}
